# %% [markdown]
# <a href="https://colab.research.google.com/github/KajPPancho/Final-Project-CS2/blob/main/Rosal_Pancho_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://raw.githubusercontent.com/KajPPancho/Rosal-Pancho-grade8-library-Repo-/refs/heads/main/books.json"
books_data = requests.get(url).json()
print(books_data)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db

cred = credentials.Certificate("firebase_key.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://rosal-pancho-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/'
})

# %%
import json

with open("books.json", "r") as file:
    data = json.load(file)
print("JSON file loaded")

refer = db.reference("books")

for book in data["books"]:
    refer.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
refer = db.reference("/")
refer.set({"books": books_data["books"]})
print(refer.get())
# Out:
# {'books': [{'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}]}

# %%
for book in refer.get()["books"]:
    print(book["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for book in refer.get()["books"]:
    print(book["title"], "-", book["details"]["available"])
# Out:
# Introduction to Python - 3
# Data Structures Basics - 2
# Web Development Essentials - 6

# %%
books_list = refer.get()["books"]


total = sum(book["details"]["copies"] for book in books_list)
print("Total number of books:", total)
# Out:
# Total number of books: 15

# %%
import requests
import json

url = "https://raw.githubusercontent.com/KajPPancho/Rosal-Pancho-grade8-library-Repo-/refs/heads/main/books.json"
response = requests.get(url)
students = response.json()

print(students)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import requests
import json

url = "https://raw.githubusercontent.com/KajPPancho/Rosal-Pancho-grade8-library-Repo-/refs/heads/main/books.json"
books_data = requests.get(url).json()
print("JSON file loaded")

ref = db.reference("books")

for book in books_data["books"]:
    ref.child(str(book["id"])).set(book)

print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!
